# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from delivery import *

# %%
env = DeliveryEnvironment(n_stops = 10)
# Out:
# Initialized Delivery Environment with 10 random stops
# Target metric for optimization is distance

# %%
env.render()

# %%
env.stops
# Out:
# [4]

# %%
for i in range(4):
    env.step(i)
env.render()

# %% [markdown]
# # Simple case

# %%
num_stops = 2000
env = DeliveryEnvironment(n_stops = num_stops, method = "distance")
# Out:
# Initialized Delivery Environment with 2000 random stops
# Target metric for optimization is distance

# %%
agent = DeliveryQAgent(env.observation_space, env.action_space)

# %%
run_n_episodes(env, agent, "training_{}_stops.gif".format(num_stops))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# (<delivery.DeliveryEnvironment at 0x226e96dffd0>,
#  <delivery.DeliveryQAgent at 0x226e98c3190>)
